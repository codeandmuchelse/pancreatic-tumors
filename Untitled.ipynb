# %%
from cmapPy.pandasGEXpress.parse_gct import parse
from cmapPy.pandasGEXpress.write_gct import write
from GSVA import gsva

# %%
listrows = [*range(128,18592,1)]

# %%
x = parse('PAAD (1).gct')

# %%
x.data_df.head(5)
# Out:
# cid      aab1-Primary solid Tumor  aab4-Primary solid Tumor  \
# rid
# SLC35E2                      7.45                       8.1
# A1BG                         6.40                       5.8
# A1CF                         4.70                       5.7
# A2BP1                       -1.00                       1.1
# A2LD1                        7.50                       6.8
#
# cid      aab6-Primary solid Tumor  aab8-Primary solid Tumor  \
# rid
# SLC35E2                       7.2                       8.0
# A1BG                          6.4                       5.8
# A1CF                          3.0                       5.1
# A2BP1                         NaN                       NaN
# A2LD1                         7.3                       7.5
#
# cid      aab9-Primary solid Tumor  aaba-Primary solid Tumor  \
# rid
# SLC35E2                      7.65                       8.1
# A1BG                         6.70                       6.6
# ...

# %%
count1 =
# Out:
#   File "<ipython-input-5-0f772f797830>", line 1
#     count1 =
#              ^
# SyntaxError: invalid syntax

# %%
count = x.data_df.shape[0] - x.data_df.dropna(inplace = False).shape[0]

# %%
print(count)

# %%
x.data_df.dropna(inplace = True)

# %%
write(x,'PAAD_new_2.gct')

# %%
y = x.data_df.duplicated()
y.value_counts()
#no duplicated values

# %%
# gene expression distribution across samples
# gene expression distribution for a sample

# %%
#pca
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
x.data_df.info()

# %%
x.col_metadata_df['histological_type'].describe()

# %%
New = x.data_df

# %%
New2 = New.T
#There is a clear biological interpretation of this statistic, 
#it emphasizes genes in pathways that are concordantly activated in one direction only, 

#This statistic may be compared to the Kuiper test statistic [29], 
#which sums the maximum and minimum deviations to make the test statistic more sensitive in the tails.
#but they don't want to check which ones are in tails, they want to see genes that mobve in one direction, not two

# %%
New2.to_csv("ExpressionData.csv", sep=',')

# %%
list_data = pd.DataFrame(["IFIT1","IFI44","IFIT3","MX2","OAS1","OAS3","BST2","IFITM1","MX1",
                  "STAT1","IFI27","CXCL10","IFI16","IFI30","IFIH1","IFIT2", 
                  "IFITM2","IRF1","IRF9","IRGM","ISG15","OAS2","PSME1","SOCS1",
                  "STAT2"])

# %%
x = gsva(New2, list_data)

# %%
from GSVA import gsva
import pandas as pd


x = GSVA.gmt_to_dataframe('Final GMT.gmt')
y = pd.read_csv('ExpressionData.csv', index_col=0).T
ans  = gsva(expression_df=y, geneset_df=x, method="gsva", kcdf="Poisson")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-ff2aea4379b5> in <module>()
#       6 x = GSVA.gmt_to_dataframe('Final GMT.gmt')
#       7 y = pd.read_csv('ExpressionData.csv', index_col=0).T
# ----> 8 ans  = gsva(expression_df=y, geneset_df=x, method="gsva", kcdf="Poisson")
#
# ~\Anaconda3\lib\site-packages\GSVA\__init__.py in gsva(expression_df, geneset_df, method, kcdf, abs_ranking, min_sz, max_sz, parallel_sz, parallel_type, mx_diff, tau, ssgsea_norm, verbose, tempdir)
#      99     destination = PIPE
#     100     if verbose: destination = sys.stderr
# --> 101     sp = Popen(cmd,stdout=PIPE,stderr=destination)
#     102     sp.communicate()
#     103     output = pd.read_csv(os.path.join(tempdir,"pathways.csv"),index_col=0)
#
# ...

# %%
df = pd.read_csv("Unnattainable Output_MetaData.csv",encoding='latin-1')

# %%
import pandas as pd
import numpy as np

# %%
#View
df.head()
# Out:
#                        name  IFN_Human_Signature  Y  \
# 0  a9is-Primary solid Tumor            -0.699527  1
# 1  6880-Primary solid Tumor            -0.690045  1
# 2  aa9m-Primary solid Tumor            -0.678347  1
# 3  a9io-Primary solid Tumor            -0.655484  1
# 4  aaaz-Primary solid Tumor            -0.641007  1
#
#                final_histological_type  mRNAseq_cluster bcr_patient_barcode  \
# 0   82463 neuroendocrine carcinoma nos                1        tcga-2j-aab1
# 1  pancreas-adenocarcinoma ductal type                2        tcga-2j-aab4
# 2  pancreas-adenocarcinoma ductal type                3        tcga-2j-aab6
# 3         neuroendocrine carcinoma nos                1        tcga-2j-aab8
# 4  pancreas-adenocarcinoma ductal type                4        tcga-2j-aab9
#
#                        bcr_patient_uuid vital_status  days_to_death  \
# 0  75119d1a-93e5-4ae7-9d60-69ee929a0772         dead             66
# ...

# %%
df = df.where(df['final_histological-type'] != "-666")
dfNew2 = df.where(df['final_histological-type'].str.contains('adeno'))
dfNew2.dropna(inplace = True)

# %% [markdown]
# dfNew = df.where(df.histological_type_other != "-666")
# dfNew2 = dfNew.where(df.histological_type_other.str.contains('adeno'))
# dfNew2.dropna(inplace = True)

# %%
df.head(20)
# Out:
#                         name  IFN_Human_Signature    Y  \
# 0   aab1-Primary solid Tumor             0.489811  1.0
# 1   aab4-Primary solid Tumor             0.658029  1.0
# 2   aab6-Primary solid Tumor             0.656896  1.0
# 3   aab8-Primary solid Tumor             0.575650  1.0
# 4   aab9-Primary solid Tumor            -0.546469  1.0
# 5   aaba-Primary solid Tumor            -0.633386  1.0
# 6   aabe-Primary solid Tumor             0.178227  1.0
# 7   aabf-Primary solid Tumor             0.667184  1.0
# 8   aabh-Primary solid Tumor            -0.481966  1.0
# 9   aabi-Primary solid Tumor            -0.521044  1.0
# 10  aabk-Primary solid Tumor             0.205542  1.0
# 11  aabo-Primary solid Tumor            -0.052688  1.0
# 12  aabp-Primary solid Tumor            -0.021069  1.0
# 13  aabr-Primary solid Tumor            -0.272351  1.0
# 14  aabt-Primary solid Tumor            -0.531859  1.0
# 15  aabu-Primary solid Tumor            -0.336805  1.0
# ...

# %%
keys = dfNew2['final_histological-type'].unique() 
keys
# Out:
# array(['invasive adenocarcinoma', 'pancreas-adenocarcinoma ductal type',
#        'poorly differentiated adenocarcinoma', 'adenocarcinoma, nos',
#        'poorly differentiated pancreatic adenocarcinoma',
#        'adenocarcinoma- nos',
#        'moderately differentiated ductal adenocarcinoma 60% + neuroendocrine 40%'],
#       dtype=object)

# %%
vals = [1,2,3,4,5,6,7]
res = {keys[i]: vals[i] for i in range(7)}

# %%
dfNew2['NewKey'] = dfNew2['final_histological-type'].replace(res)

# %%
range(len(keys))
# Out:
# range(0, 7)

# %%
dfNew2.plot.scatter(x=1,y=2,c=4)

# %%
dfNew2.head(15)
# Out:
#                         name  IFN_Human_Signature    Y  \
# 0   aab1-Primary solid Tumor             0.489811  1.0
# 1                        NaN                  NaN  NaN
# 2   aab6-Primary solid Tumor             0.656896  1.0
# 3   aab8-Primary solid Tumor             0.575650  1.0
# 4   aab9-Primary solid Tumor            -0.546469  1.0
# 5   aaba-Primary solid Tumor            -0.633386  1.0
# 6   aabe-Primary solid Tumor             0.178227  1.0
# 7   aabf-Primary solid Tumor             0.667184  1.0
# 8   aabh-Primary solid Tumor            -0.481966  1.0
# 9   aabi-Primary solid Tumor            -0.521044  1.0
# 10  aabk-Primary solid Tumor             0.205542  1.0
# 11  aabo-Primary solid Tumor            -0.052688  1.0
# 12                       NaN                  NaN  NaN
# 13  aabr-Primary solid Tumor            -0.272351  1.0
# 14  aabt-Primary solid Tumor            -0.531859  1.0
#
#                  final_histological-type NewKey
# ...

# %%
res
# Out:
# {'invasive adenocarcinoma': 1,
#  'invasive, well-differentiated': 2,
#  '-666': 3,
#  'poorly differentiated adenocarcinoma': 4,
#  'neuroendocrine': 5,
#  'neuroendocrine carcinoma nos': 6,
#  '82463 neuroendocrine carcinoma nos': 7,
#  'neuroendocrine carcinoma': 8,
#  'adenocarcinoma, nos': 9,
#  'poorly differentiated pancreatic adenocarcinoma': 10,
#  'not specified': 11,
#  'intraductal tubulopapillary neoplasm': 12,
#  'ductal and micropapillary': 13,
#  'adenocarcinoma- nos': 14,
#  'moderately differentiated ductal adenocarcinoma 60% + neuroendocrine 40%': 15}

# %%
dfNew2.sort_values(by = 'IFN_Human_Signature',inplace = True)

# %%
dfNew2['Signature_key'] = range(len(dfNew2['name']))

# %%
dfNew2.head(100)
# Out:
#                          name  IFN_Human_Signature    Y  \
# 43   6880-Primary solid Tumor            -0.690045  1.0
# 161  aa9m-Primary solid Tumor            -0.678347  1.0
# 41   aaaz-Primary solid Tumor            -0.641007  1.0
# 140  aaum-Primary solid Tumor            -0.634101  1.0
# 5    aaba-Primary solid Tumor            -0.633386  1.0
# 68   8124-Primary solid Tumor            -0.620581  1.0
# 97   8636-Primary solid Tumor            -0.601090  1.0
# 172  aaug-Primary solid Tumor            -0.600099  1.0
# 110           a9tj-Metastatic            -0.599992  1.0
# 108  a8p0-Primary solid Tumor            -0.594871  1.0
# 173  aauh-Primary solid Tumor            -0.587855  1.0
# 39   a9j0-Primary solid Tumor            -0.571830  1.0
# 56   aapp-Primary solid Tumor            -0.571751  1.0
# 125  7890-Primary solid Tumor            -0.571091  1.0
# 95   8317-Primary solid Tumor            -0.561036  1.0
# 87   7924-Primary solid Tumor            -0.556586  1.0
# ...

# %%
dfNew2.plot.scatter(x=1,y=2,c=5)
